# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('DATA/rainbow.jpg',0)
plt.imshow(img,cmap='gray')

# %%
img.max()
# Out:
# 214

# %%
ret,thresh1 = cv2.threshold(img,thresh = 127,maxval = 255,type = cv2.THRESH_TRUNC)

# %%
ret
# Out:
# 127.0

# %%
type(thresh1)
# Out:
# numpy.ndarray

# %%
thresh1
# Out:
# array([[107, 107, 107, ..., 127, 127, 127],
#        [103, 103, 103, ..., 127, 127, 127],
#        [103, 103, 103, ..., 127, 127, 127],
#        ...,
#        [115, 115, 115, ...,  88,  89,  91],
#        [116, 116, 116, ...,  89,  91,  93],
#        [118, 118, 118, ...,  93,  94,  96]], dtype=uint8)

# %%
plt.imshow(thresh1,cmap='gray')

# %%
img = cv2.imread('DATA/crossword.jpg',0)
plt.imshow(img,cmap = 'gray')

# %%
def show_pic(img):
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap = 'gray')

# %%
show_pic(img)

# %%
ret,th1 = cv2.threshold(img,thresh = 170,maxval = 255,type = cv2.THRESH_BINARY)
show_pic(thresh1)

# %%
th2 = cv2.adaptiveThreshold(img,maxValue=255,
                            adaptiveMethod=cv2.ADAPTIVE_THRESH_MEAN_C,
                            thresholdType=cv2.THRESH_BINARY,
                            blockSize=7,
                            C=8)
show_pic(th2)

# %%
blended = cv2.addWeighted(src1=th1,alpha=0.6,src2=th2,beta=0.4,gamma=0)
show_pic(blended)
